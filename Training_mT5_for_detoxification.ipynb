# %% [markdown]
# # Train mT5 for RUSSE Detox 2022

# %% [markdown]
# ## Proprocess data

# %%
# !git clone https://github.com/skoltech-nlp/russe_detox_2022
# Out:
# Cloning into 'russe_detox_2022'...
# remote: Enumerating objects: 82, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 82 (delta 22), reused 43 (delta 16), pack-reused 29
# Unpacking objects: 100% (82/82), done.

# %%
import re
import pandas as pd

# пока что мы объединяем dev и train: не хотим валидироваться на обучении, раз существует test-сет
data_df = pd.concat([
           pd.read_csv("./russe_detox_2022/data/input/dev.tsv", sep="\t"),
           pd.read_csv("./russe_detox_2022/data/input/train.tsv", sep="\t").drop(["index"], axis=1)
], axis=0).reset_index(drop=True)

# если у фразы несколько вариантов исправления — просто кладём их все как пары input-target
# исходим из того, что наши модели достаточно complex, чтобы это их не запутало
train_dict = {
    "input": [],
    "target": []
}

for tc, nc1, nc2, nc3 in zip(list(data_df["toxic_comment"]), list(data_df["neutral_comment1"]),
                             list(data_df["neutral_comment2"]), list(data_df["neutral_comment3"])):
  # здесь немножко препроцесса: из-за особенностей sentencepiece-токенизации модели плохо понимают
  # текст, написанный КАПСОМ. мы будем смотреть, если во входной строке больше 50% символов — капс,
  # и в таком случае приводить её к нижнему регистру
  input_str = str(tc)
  if len([c for c in input_str if re.search(r"[A-ZА-ЯЁ]", c)]) / len(input_str) > 0.5:
    input_str = input_str.lower()

  train_dict["input"].append(input_str)
  train_dict["target"].append(str(nc1))
  if type(nc2) != float: # проверка на NaN
    train_dict["input"].append(input_str)
    train_dict["target"].append(str(nc2))
  if type(nc3) != float: # проверка на NaN
    train_dict["input"].append(input_str)
    train_dict["target"].append(str(nc3))

train_df = pd.DataFrame(train_dict)

# перемешиваем датасет; задаём seed, чтобы результаты перемешивания совпадали между разными запусками
train_df = train_df.sample(frac=1, random_state=42).reset_index(drop=True)

# и всё, этого достаточно! токенизаторы у каждой модели свои, лемматизация и другая нормализация
# только уменьшат количество полезных данных для transformer-нейросетей

# пример того, что у нас в датафрейме:
train_df.sample(10)
# Out:
#                                                    input  \
# 463            а мне не сделал, вот хуй ты печальный :-(
# 3089         мне скуучноо(( может опять твиты посвящать?
# 8116   Отвалите от Волгограда, ублюдки, я не могу это...
# 12068  Каникулы. А я сука сижу дома из-за ебаной пого...
# 7599   С кем? С каким-то независимым оператором ? Что...
# 5138   автор иди ты на хуй со своими классами деду он...
# 5994   только заметила, что измазала кровью всю дубле...
# 12146          алгебра, литер и русск дописать!( а тебе?
# 7503   да а я сегодня познакомилась нехотя с блядью мужа
# 11317  спартак мы всеровно с тобой остальные пусть ху...
#
#                                                   target
# 463                   А мне не сделал, вот ты печальный.
# 3089            Мне скучно. Может опять твиты посвящать?
# 8116       Отстаньте от Волгограда, я не могу это читать
# 12068       Каникулы. А я сижу дома из-за плохой погоды.
# 7599   С кем? С каким-то независимым оператором? Что ...
# 5138   автор отстань со своими классами деду они и со...
# 5994   только заметила, что измазала кровью всю дубле...
# 12146  Алгебру,литературу и русский язык дописать. А ...
# 7503   Да я сегодня познакомилась нехотя с любовницей...
# 11317  Спартак мы все равно с тобой, остальные пускай...

# %% [markdown]
# ## Train mT5 (Google)

# %%
# устанавливаем необходимые библиотеки
# !pip install -qqq happytransformer sentencepiece
# Out:
#      |████████████████████████████████| 45 kB 2.5 MB/s
#      |████████████████████████████████| 1.2 MB 17.3 MB/s
#      |████████████████████████████████| 325 kB 50.4 MB/s
#      |████████████████████████████████| 3.8 MB 42.6 MB/s
#      |████████████████████████████████| 67 kB 1.2 MB/s
#      |████████████████████████████████| 1.1 MB 45.0 MB/s
#      |████████████████████████████████| 212 kB 52.5 MB/s
#      |████████████████████████████████| 134 kB 57.5 MB/s
#      |████████████████████████████████| 127 kB 50.4 MB/s
#      |████████████████████████████████| 596 kB 61.6 MB/s
#      |████████████████████████████████| 6.5 MB 62.7 MB/s
#      |████████████████████████████████| 895 kB 58.8 MB/s
#      |████████████████████████████████| 94 kB 4.2 MB/s
#      |████████████████████████████████| 144 kB 54.0 MB/s
#      |████████████████████████████████| 271 kB 75.0 MB/s
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.

# %%
import csv

# подготавливаем обучающие данные
train_df.to_csv("train.csv", index=False, quoting=csv.QUOTE_ALL)

# %%
from happytransformer import HappyTextToText, TTTrainArgs
from transformers import AutoTokenizer

# берём модель mt5 от Google, размер чекпойнта base
model = HappyTextToText("T5", "google/mt5-base")

# 2 эпохи обучения
args = TTTrainArgs(num_train_epochs=2) 
model.train("train.csv", args=args)
# Out:
# 03/20/2022 20:44:54 - INFO - happytransformer.happy_transformer -   Using model: cuda
# 03/20/2022 20:45:09 - INFO - happytransformer.happy_transformer -   Preprocessing training data...
# Downloading and preparing dataset csv/default to /root/.cache/huggingface/datasets/csv/default-c571bc2c2d2dbe9b/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-c571bc2c2d2dbe9b/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/13 [00:00<?, ?ba/s]
# 03/20/2022 20:45:24 - INFO - happytransformer.happy_transformer -   Training...
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 12206
#   Num Epochs = 2
#   Instantaneous batch size per device = 1
#   Total train batch size (w. parallel, distributed & accumulation) = 1
#   Gradient Accumulation steps = 1
#   Total optimization steps = 24412
#     <div>
#
#       <progress value='23610' max='24412' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [23610/24412 2:07:32 < 04:19, 3.08 it/s, Epoch 1.93/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>6.060500</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>2.623600</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>2.264100</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>2.106700</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>2.136800</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>2.002200</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>1.855600</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>1.770500</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>1.718300</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>1.672600</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>1.694200</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>1.582200</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>1.652800</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>1.663900</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>1.615300</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>1.543900</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>1.525300</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>1.555500</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>1.527900</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>1.476200</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>1.501100</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>1.563900</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>1.530800</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>1.483100</td>
#     </tr>
#     <tr>
#       <td>12500</td>
#       <td>1.417600</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>1.399000</td>
#     </tr>
#     <tr>
#       <td>13500</td>
#       <td>1.329700</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>1.345000</td>
#     </tr>
#     <tr>
#       <td>14500</td>
#       <td>1.346000</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>1.315600</td>
#     </tr>
#     <tr>
#       <td>15500</td>
#       <td>1.335100</td>
#     </tr>
#     <tr>
#       <td>16000</td>
#       <td>1.348100</td>
#     </tr>
#     <tr>
#       <td>16500</td>
#       <td>1.316500</td>
#     </tr>
#     <tr>
#       <td>17000</td>
#       <td>1.258100</td>
#     </tr>
#     <tr>
#       <td>17500</td>
#       <td>1.278000</td>
#     </tr>
#     <tr>
#       <td>18000</td>
#       <td>1.306200</td>
#     </tr>
#     <tr>
#       <td>18500</td>
#       <td>1.310800</td>
#     </tr>
#     <tr>
#       <td>19000</td>
#       <td>1.286500</td>
#     </tr>
#     <tr>
#       <td>19500</td>
#       <td>1.295500</td>
#     </tr>
#     <tr>
#       <td>20000</td>
#       <td>1.289700</td>
#     </tr>
#     <tr>
#       <td>20500</td>
#       <td>1.308900</td>
#     </tr>
#     <tr>
#       <td>21000</td>
#       <td>1.273600</td>
#     </tr>
#     <tr>
#       <td>21500</td>
#       <td>1.279300</td>
#     </tr>
#     <tr>
#       <td>22000</td>
#       <td>1.263500</td>
#     </tr>
#     <tr>
#       <td>22500</td>
#       <td>1.219700</td>
#     </tr>
#     <tr>
#       <td>23000</td>
#       <td>1.256000</td>
#     </tr>
#     <tr>
#       <td>23500</td>
#       <td>1.284100</td>
#     </tr>
#   </tbody>
# </table><p>

# %% [markdown]
# ## Evaluate model

# %%
from tqdm.notebook import tqdm

# подготавливаем тест сет
test_df = pd.read_csv("./russe_detox_2022/data/input/test.tsv", sep="\t")
output = [model.generate_text(entry) for entry in tqdm(list(test_df["toxic_comment"]))]
output[:20]

# %%
# сохраняем предсказания, подготавливаем для кодалаба
with open("output_mt5_base_2.txt", "w") as out_file:
    out_file.write("\n".join([entry.text for entry in output]))

# !zip output_mt5_base_2.zip output_mt5_base_2.txt

# %% [markdown]
# ## Export model

# %%
# сохраняем модель
model.save("mt5_base_2/")
# !tar -czf mt5_base_2.tar.gz mt5_base_2

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# выгружаем веса на гугл диск

#!mkdir /content/drive/MyDrive/rudetox
# !cp mt5_base_2.tar.gz /content/drive/MyDrive/rudetox
# !cp output_mt5_base_2.zip /content/drive/MyDrive/rudetox
